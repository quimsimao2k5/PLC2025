# %% [markdown]
# ## Sobre Python
#
# Python é uma linguagem de programação de alto nível que pode ser usada em vários domínios (e.g.: aplicações web, processamento de língua natural, machine learning, etc.). É dinamicamente tipada e possui coletor de lixo. Suporta ainda vários paradigmas de programação (funcional, imperativo, orientado a objetos).

# %% [markdown]
# ### Exemplo de programas simples em Python

# %%
def main():
  print("Hello World!")
# O que falta ?

# %% [markdown]
# Ao contrário de linguagens como C, nas quais a função `main` determina o fluxo de execução, em Python apenas o código *top-level* é executado, isto é, o código no nível superior do ficheiro, fora de qualquer função ou classe.

# %%
def teste():
  print("esta frase não é impressa.")

print("esta frase é impressa.")
teste()

# %% [markdown]
# ## Tipos de dados primitivos

# %% [markdown]
# ### Inteiros

# %%
x = 5
y = 3
x=8
print(x)
print(x + y) # pq?

# %% [markdown]
# ### Booleanos

# %%
a = 10 < 5
print(a)
print(a or True)
print(1 and (True or []) and not False)

# %% [markdown]
# ### Reais

# %%
media = (13+18+12)/3
print(media)
print(type(media))
print(round(media, 2))

# %% [markdown]
# ### Strings

# %%
frase = "Amor é fogo que arde sem se ver"

# Acesso a um caracter
print(frase[12])
# Slicing
print(frase[5:12])
# A contar do fim: índices negativos
print(frase[-3:])
# Cada N caracteres:
print(frase[::3])
# Inverter string:
print(frase[::-1])

# %%
frase = "Amor é fogo que arde sem se ver"

# Comprimento e concatenação de strings
print("A frase tem " + str(len(frase)) + " carateres.")

print("Vamos iterar sobre a string:")
for c in frase:
    print(c)

# %%
# Partir uma string em substrings usando um ou mais caracteres como separador
frase = "Amor é fogo que arde sem se ver"
# tiago@gmaiol.com
palavras = frase.split()
print(palavras)
# O resultado é uma lista, vamos ver à frente...

# %%
# ATENÇÃO: Python não tem nenhum tipo 'char'
frase = "Amor é fogo que arde sem se ver"
print(type(frase[0])) #  string ou char?

# %% [markdown]
# ## Condicionais

# %%
if 10 > 5:
  print("Está tudo bem!")
elif 10>70:
  print("ok")
else: # o bloco 'else' é opcional
  print("Passa-se algo de estranho...")

# %%
idade = 22
if idade < 18:
  print("Ainda não pode beber")
else:
  print("Se calhar não devia beber")

# %% [markdown]
# ## Ciclos

# %% [markdown]
# ### Ciclo for

# %%
for i in [1,2,3,4,5]:
  print(i)

print("-----")

# ou
for i in range(1,6):
  print(i)

# %% [markdown]
# ### Ciclo while

# %%
i = 5
while i > 0:
  print(i)
  i -= 1 # Python não possui sintaxe ++/--

# %% [markdown]
# ## Ler input do terminal

# %%
idade = input("Quantos anos tens?") # devolve sempre uma string
print(type(idade))
idade = int(idade) # convertemos a string para um inteiro
print(idade)

# %% [markdown]
# ## Definição de funções
#
# Sintaxe:
#
# ```
# def nome(arg1, arg2, ...):
#     instruções
#     [return resultado]
# ```

# %%
def add(a,b):
    return a+b

print(add(7,12))
print(add(add(2,3),4))

# %%
def fact(n):
  if n == 0: return 1
  return n * fact(n - 1)

print(fact(5))

# %% [markdown]
# ### 1 - Exercício simples
#
# Especifique uma função, primeiro recursiva e depois iterativa, para calcular o resultado de elevar uma base a um determinado expoente.
# Depois escreva um programa que leia uma base B e dois expoentes Einf e Esup e imprima todas as potências de B entre Einf e Esup, usando uma das funções anteriores.

# %%
def pot_recursiva(b, e):
    if e == 0: return 1
    else:
       return pot_recursiva(b, e-1) * b

def pot_iterativa(b, e):
    res = 1
    while e != 0:
       res = res * b 
       e = e - 1
    return res

base = int(input("Base: "))
einf = int(input("Expoente inferior: "))
esup = int(input("Expoente superior: "))

for e in range(einf, esup + 1):
  print(str(base) + "^" + str(e) + " = " + str(pot_recursiva(base, e)))
  print(str(base) + "^" + str(e) + " = " + str(pot_iterativa(base, e)))

# %% [markdown]
# ## Tipos de dados estruturados:

# %% [markdown]
# ### TE1: Listas
#
# Uma lista é uma sequência finita e ordenada de elementos. Um elemento pode ser qualquer coisa.

# %% [markdown]
# #### Construtores:

# %%
# lista vazia
l = [] # ou: l = list()
# lista homogénea
l2 = [1,2,3,4,5]
# lista heterogénea
l3 = [11, "onze", 12, "doze"]
# lista a partir de *range*
l4 = list(range(1,11))
# range != lista
print(type(range(1,11)))

# listas por compreensão
l5 = [x for x in range(1,10) if x % 2 == 0]
print(l5)

l6 = [x for x in range(1,1001) if x % 23 == 0]
print(l6)

# %%
frase = "Amor é fogo que arde sem se ver"
palm3 = [x for x in frase.split() if len(x) > 3]
print(palm3)

# %% [markdown]
# #### Comprimento

# %%
vogais = ['a', 'e', 'i', 'o', 'u']
print(len(vogais))

# %% [markdown]
# #### _in_ e _not in_

# %%
texto = "HELOASQTS-+"
texto = texto.lower()
vogaisPresentes = []
vogais="aeiou"
for v in vogais:
    if v not in texto:
        vogaisPresentes.append(False)
    else:
        vogaisPresentes.append(True)
print(vogaisPresentes)

# %% [markdown]
# #### Acrescentar elementos a uma lista

# %%
pares100 = []
i = 0
while i <= 100:
  if i % 2 == 0:
    pares100.append(i)
  i += 1
  print(i, end=" ")
print(pares100)

# [x for x in range(0,101) if x % 2 == 0]

# %% [markdown]
# #### Apagar o conteúdo duma lista

# %%
print(pares100.pop(1))
print(pares100)

pares100.clear()
print(pares100)

# %% [markdown]
# #### Copiar uma lista

# %%
cores = ["vermelho", "verde", "azul"]
cores2 = cores.copy() + ["amarelo"]
print(cores2)
print(cores2.index("verde"))

# %%
for i, cor in enumerate(cores2):
    print(str(i) + ": " + cor)

# %% [markdown]
# #### Inserir um elemento numa determinada posição

# %%
cores2.insert(1, "roxo")
print(cores2)

# %% [markdown]
# #### Remover a primeira ocorrência de um elemento

# %%
cores2 = cores2 + ["verde", "verde"]
print(cores2)
cores2.remove("verde")
print(cores2)

# %% [markdown]
# #### Ordem e ordenação

# %%
lista = [x for x in range(1,21)]
print(lista)
lista.reverse()
print(lista)
# lista.sort()
lista2 = sorted(lista)
print(lista2)

# %% [markdown]
# #### 2 - Exercício: maior elemento de uma lista

# %%
def maior(lista):
  res = None
  for elem in lista:
    if not res or elem > res:
      res = elem
  return res

print(maior([4,2,5,1,3]))

# %% [markdown]
# ### TE2: Tuplos
#
# Tuplos podem conter elementos de qualquer tipo, mas o seu comprimento não pode ser alterado.

# %% [markdown]
# #### Construtores: (), tuple()

# %%
estudante1 = ("Jane Doe", "A00000", "ENGINF", 21, False, True, True, False)
coordenadas = tuple([39, 9])

# %% [markdown]
# #### Acesso

# %%
curso1 = estudante1[2]
print(curso1)

# %% [markdown]
# #### Acesso com desmembramento (unfold/unpack)

# %%
nome, id, curso, idade, *presencas = estudante1
print(id + ": " + nome)
print(presencas)

# %% [markdown]
# #### Testar se um valor está no tuplo

# %%
if False in estudante1:
    print("Faltou pelo menos uma vez!")

if True in presencas:
    print("Veio a pelo menos 1 aula...")

# %% [markdown]
# Para remover um elemento de um tuplo, precisamos de criar um tuplo novo.

# %% [markdown]
# #### 3 - Exercício: unzip
#
# A partir de uma lista de tuplos, define duas listas.

# %%
def unzip(l):
  l1 = []
  l2 = []
  for num, fruta in l:
    l1.append(num)
    l2.append(fruta)
  return (l1, l2)

lista = [(1, "banana"), (2, "maçã"), (3, "melancia"), (4, "cereja")]

(unzipped1, unzipped2) = unzip(lista)
print(unzipped1)
print(unzipped2)

# %% [markdown]
# ### TE3: Dicionários
#
# #### Construtores: {}, dict()

# %%
d1 = dict()
d1["Python"] = True
print(d1)

d2 = {"Python" : 6, "Haskell" : 15, "Web" : { "HTML" : 20, "CSS": 13}}
print(d2)
print(d2["Web"]["CSS"])

# a partir de uma lista de tuplos
d3 = dict([(1, "banana"), (2, "maçã"), (3, "melancia"), (4, "cereja")])
print(d3)

# %% [markdown]
# #### Acesso

# %%
compras = {'maçã': 5, 'laranja':6, 'banana': 7}
print(compras['laranja'])
print(compras.get('melancia', "Não existe!"))

# %% [markdown]
# #### Extrair chaves

# %%
distrib = {"LCC": 23, "ENGBIOM": 35, "LEI": 32, "ENGFIS": 17}
chaves = list(distrib.keys())
print(chaves)

# %% [markdown]
# #### Extrair valores

# %%
distrib = {"LCC": 23, "ENGBIOM": 35, "LEI": 32, "ENGFIS": 17}
valores = distrib.values()
print(valores)

# %% [markdown]
# #### Concatenar dicionários

# %%
legumes = {"cenouras": 6, "batatas":20, "cebolas": 12}
frutas = {"tangerina": 30, "pêras":8, "bananas": 6, "romãs": 2}
charcutaria = {"fiambre": 10, "queijo": 16, "chouriço": 1}
listaCompras = legumes.copy()
listaCompras.update(frutas)
listaCompras.update(charcutaria)
print(listaCompras)

# %%
legumes = {"cenouras": 6, "batatas":20, "cebolas": 12}
frutas = {"tangerina": 30, "pêras":8, "bananas": 6, "romãs": 2}
charcutaria = {"fiambre": 10, "queijo": 16, "chouriço": 1}
listaCompras = {}
for chave in legumes.keys():
    listaCompras[chave] = legumes[chave]
for chave in frutas.keys():
    listaCompras[chave] = frutas[chave]
for chave in charcutaria:
    listaCompras[chave] = charcutaria[chave]
print(listaCompras)

# %% [markdown]
# #### Verificar se uma chave está no dicionário

# %%
def pertenceChave(c, d):
    return (c in d)

# %%
print(pertenceChave("bananas", listaCompras))
print(pertenceChave("beterrabas", listaCompras))

# %% [markdown]
# #### 4 - Exercício:
#
# Escreve um programa em Python que leia um número inteiro positivo e crie um dicionário com chaves de 1 até esse número, em que o valor associado a cada chave é o quadrado dessa chave.

# %%
v = int(input("introduz um valor: "))
d = {}
# d = {x:x*x for x in range(1,v+1) }

for x in range(1,v+1):
    d[x] = x*x
print(d)

# %% [markdown]
# ## Funções de Ordem Superior
#
# Em certas situações, poderá ser preferível ou até mais eficiente usar funções de ordem superior em vez de algoritmos iterativos ou compreensão de listas.

# %% [markdown]
# ### Map

# %%
dobros = map(lambda x: x * 2, range(1,6))
print(dobros) # funções como a map são preguiçosas, ou seja, só processam os
              # seus valores quando estes são necessários
print(list(dobros)) # forçamos o map a processar os valores, colocando-os numa lista

# %% [markdown]
# ### Filter

# %%
def isEven(n):
  return n % 2 == 0

evens = filter(isEven, range(1,11))
print(list(evens))

# %% [markdown]
# ### Fold / reduce

# %%
from functools import reduce

lista = [3,5,4,6,1,2]
maior = lista[0]
# print("O maior elemento é:", reduce(lambda acc, x: x if x > acc else acc, lista, maior))
print("O maior elemento é:", reduce(lambda acc, x: x if x > acc else acc, lista, lista[0]))
# reduce(function, sequence[, initial]) é equivalente ao `foldl` de Haskell

# %%
lista = [3,5,4,6,1,2]
def soma(acc, elem):
    return acc + elem

print("A soma é:", reduce(soma, lista, lista[0]))

# %% [markdown]
# ## Input e Output de ficheiros

# %% [markdown]
# Modos de abertura de um ficheiro:
# * "r" - Read - Valor por omissão. Abre o ficheiro para leitura, devolve error se o ficheiro não existir;
# * "a" - Append - Abre o ficheiro para acrescentar, cria o ficheiro se este não existir;
# * "w" - Write - Abre o ficheiro para escrever, cria o ficheiro se este não existir, apaga o conteúdo se este existir;
# * "x" - Create - Cria o ficheiro, devolve error se o ficheiro já existir.
#
# Parâmetro adicional ao modo:
# * "t" - Text - Valor por omissão. Ficheiro textual;
# * "b" - Binary - Ficheiro binário, por exemplo, imagens.

# %%
f = open("teste.txt", "rt")
content = f.read() # string
print(len(content.split()))
f.close() # Não esquecer de fechar o ficheiro

# %% [markdown]
# ### Ler linha a linha dum ficheiro

# %%
f = open("teste.txt")
for linha in f:
  print(linha, end="")

# %% [markdown]
# ### Ler a primeira e a segunda linha de um ficheiro

# %%
f = open("teste.txt")
linha1 = f.readline()
linha2 = f.readline()
print(linha1, linha2)

# %% [markdown]
# ### Ler o ficheiro de uma vez

# %%
with open("teste.txt") as f:
  content = f.read()

# %% [markdown]
# ### Escrever no ficheiro

# %%
with open("output.txt", "w") as f:
  f.write("O ficheiro só vai ter esta linha de texto.")

# %% [markdown]
# ### Ler do stdin
# Muitos dos programas nesta UC devem ler do stdin (canal de entrada do SO).

# %%
import sys
linhas = 0
pals = 0
chars = 0

for linha in sys.stdin:
  linhas = linhas + 1
  pals = pals + len(linha.split())
  chars = chars + len(linha)

print(linhas, chars)

# %% [markdown]
# ## F-strings
#
# A forma mais fácil de imprimir strings formatadas em Python é através de f-strings.
#
# Apenas colocamos um `f` antes das aspas iniciais e podemos inserir variáveis diretamente dentro de uma string com chavetas.

# %%
num1 = 5
num2 = 8

print(f"A soma de {num1} com {num2} é {num1 + num2}.")
print(f"{5/3:05.3}")

# %% [markdown]
# # Exercícios

# %% [markdown]
# **1**
# Partindo do dataset [alunos.csv](https://epl.di.uminho.pt/~jcr/AULAS/ATP2021/datasets/alunos.csv) :
# 1. Leia e imprima todas as entradas do ficheiro csv
# 2. Crie uma função que verifique quantas linhas tem o ficheiro
# 3. Crie um dicionário para albergar todas as informações relativas a um aluno com o formato:
# {
# id_aluno : (
# notas:[TPC1,TPC,TPC3,TPC4],
# nome:"NOME",
# curso:"CURSO"
# )
# }
#
#   3.1 Quais os alunos com melhor média ?
#
#   3.2 Quantos alunos de LEI tem a média dos tpcs superior a 15?
#
# **2**
# Partindo do dataset [cinema.json](https://epl.di.uminho.pt/~jcr/AULAS/ATP2021/datasets/cinemaATP.json) :
# 1. Carregue a informação presente no dataset para uma estrutura à sua escolha
# 2. Crie diferentes funções de maneira a que seja possível
#   1. Consultar um filme na base de dados: a partir do id ou a partir do título, por exemplo "Todos os filmes com a palavra office no título;
#   2. Listar todos os filmes por ordem alfabética de título;
#   3. Listar todos os filmes de um determinado género;
#   4. Listar todos os filmes de um determinado ator;
#   5. Produzir os seguintes indicadores estatísticos:
#      1. Quantos filmes existem na BD?
#      2. Qual a distribuição dos filmes por género?
#      3. Qual a distribuição de filmes por ator (apenas o top10)?

# %% [markdown]
# ## Notas de apoio para trabalhar com ficheiros csv e json

# %%
#Escrita e leitura de csv
import csv
with open('alunos.csv', mode ='r')as file:
    ficheiro = csv.reader(file)
    for linha in ficheiro:
        print(linha)

# Escrita e leitura de json
import json
f=open("cinema.json","r")
dados =json.load(f) 
for i in dados:
    print(i)

# %% [markdown]
# # Resoluções dos alunos

# %%
#Ex Crie um dicionário para albergar todas as informações relativas a um aluno com o formato:
import csv
d = {}
with open('alunos.csv', mode='r', encoding='latin-1') as file:
    ficheiro = csv.reader(file)
    next(ficheiro)
    for linha in ficheiro:
        id_aluno = linha[0]
        nome = linha[1]
        curso = linha[2]
        notas = [int(linha[3]), int(linha[4]), int(linha[5]), int(linha[6])]
        d[id_aluno] = {
            "notas": notas,
            "nome": nome,
            "curso": curso
        }

def calcula_media(id_aluno):
    return sum(d[id_aluno]["notas"])/4

r = 0
for aluno in d:
    if calcula_media(aluno) >= 15 and d[aluno]["curso"] == 'LEI':
        r += 1
print(f"Alunos de LEI com média superior a 15 valores {r}")

# Encontrar a(s) melhor(es) média(s)
medias = {aluno_id: calcula_media(aluno_id) for aluno_id in d}
melhor_media = max(medias.values())
melhores_ids = [aluno_id for aluno_id, media in medias.items() if media == melhor_media]

for melhor_id in melhores_ids:
    print(f"Aluno com melhor média: {d[melhor_id]['nome']} (ID: {melhor_id}) - {melhor_media:.2f}")
melhor_media = calcula_media(melhor_id)
# Out:
# Alunos de LEI com média superior a 15 valores 6
# Aluno com melhor média: MoisÃ©s JoÃ£o Cornelio (ID: a47) - 18.00
# Aluno com melhor média: Maria Carolina JosuÃ© (ID: a80) - 18.00

# %%
#ex json
import json
f = open("cinema.json", "r", encoding="utf-8")
dados = json.load(f)
filmes = {}

# Carregue a informação presente no dataset para uma estrutura à sua escolha
for filme in dados["filmes"]:
    filmes[filme["title"]]=filme

# Consultar um filme na base de dados: a partir do id ou a partir do título, por exemplo "Todos os filmes com a palavra office no título;
def consultaFilme(input):
    resultados = [filme for titulo, filme in filmes.items() if input.lower() in titulo.lower()]
    return resultados

#Listar todos os filmes por ordem alfabética de título;
def filmesOrdenados():
    return sorted(filmes.values(),key= lambda x:x["title"])

# Listar todos os filmes de um determinado género;
def searchFilmesPorGenero(gen):
    return [f for fil in filmes if gen in fil['genres']]

# Listar todos os filmes de um determinado ator;
def searchfilmesPorAtor(ator):
    return [f for fil in filmes if ator in fil['cast']]

# Quantos filmes existem na BD?
def totalFilmes():
    return len(filme)

# Qual a distribuição dos filmes por género?
def filmesPorGeneroDict():
    generos_dict = {}
    for filme in filmes.values():
        for genero in filme.get('genres', []):
            if genero not in generos_dict:
                generos_dict[genero] = []
            generos_dict[genero].append(filme['title'])
    return generos_dict

# Qual a distribuição de filmes por ator (apenas o top10)?
def filmesPorAtor(top_n=10):
    atores_dict = {}
    for filme in filmes.values():
        for ator in filme.get('cast', []):
            if ator not in atores_dict:
                atores_dict[ator] = []
            atores_dict[ator].append(filme['title'])
    return sorted(atores_dict.items(), key=lambda x: len(x[1]), reverse=True)[:top_n]

print(filmesPorAtor())

for ator in filmesPorAtor(10000):
    print(f"Nome: {ator[0]} -> {len(ator[1])} filmes")
# Out:
# [('and', ['Scratch', 'Biggie & Tupac', 'Dig!', 'Encounter Point', 'Flock of Dodos', 'Hip-Hop: Beyond Beats and Rhymes', 'Hurricane on the Bayou', 'Beyond Belief', 'For the Bible Tells Me So', 'Manda Bala (Send a Bullet)', 'Operation Homecoming: Writing the Wartime Experience', 'ShowBusiness: The Road to Broadway', 'Sicko', 'Expelled: No Intelligence Allowed', 'It Might Get Loud', 'Battle: Los Angeles', 'Cedar Rapids', 'The Double', 'Father of Invention', 'Final Destination 5', 'A Good Old Fashioned Orgy', 'Green Lantern', 'The Hangover: Part II', 'Hanna', 'Hesher', 'Horrible Bosses', 'Hugo', 'The Ides of March', 'Insidious', 'J. Edgar', 'Jack and Jill', 'Janie Jones', 'Killer Elite', 'The Perfect Host', 'Pirates of the Caribbean: On Stranger Tides', 'The Rum Diary', 'Straw Dogs', 'A Very Harold & Kumar 3D Christmas', 'Casa de Mi Padre', 'Celeste and Jesse Forever', 'The Cold Light of Day', 'Flight', 'For a Good Time, Call...', 'Haywire', 'High School', 'House at the End of the Street', 'The Hunger Games', 'Magic Mike', 'The Oogieloves in the Big Balloon Adventure', 'Red Lights', 'Stolen', 'Taken 2', 'The Tall Man', 'This Is 40', 'Total Recall', 'Touchback', 'Trouble with the Curve', 'Underworld: Awakening', 'Virginia', 'The Vow', 'Wanderlust', "Won't Back Down", 'The Words', 'Wrath of the Titans', 'Wreck-It Ralph', 'The Conjuring', 'Olympus Has Fallen', 'Paranoia', 'Parker', 'Planes', 'Temptation: Confessions of a Marriage Counselor', 'Texas Chainsaw 3D', 'Thor: The Dark World', 'Warm Bodies', 'Wrong']
# Nome: Matt Damon -> 34 filmes
# Nome: John Goodman -> 34 filmes
# Nome: Nicolas Cage -> 34 filmes
# Nome: Johnny Depp -> 33 filmes
# Nome: James Franco -> 33 filmes
# Nome: Mark Wahlberg -> 32 filmes
# Nome: Stanley Tucci -> 31 filmes
# Nome: Alec Baldwin -> 30 filmes
# Nome: Dwayne Johnson -> 29 filmes
# Nome: Susan Sarandon -> 29 filmes
# Nome: Woody Harrelson -> 29 filmes
# Nome: Will Ferrell -> 28 filmes
# Nome: Colin Farrell -> 28 filmes
# Nome: Scarlett Johansson -> 28 filmes
# Nome: Ewan McGregor -> 28 filmes
# Nome: Nicole Kidman -> 28 filmes
# Nome: Paul Giamatti -> 27 filmes
# Nome: Dennis Quaid -> 27 filmes
# Nome: James Marsden -> 27 filmes
# Nome: Jack Black -> 27 filmes
# Nome: Ben Stiller -> 27 filmes
# Nome: Hugh Jackman -> 27 filmes
# Nome: Ryan Reynolds -> 27 filmes
# Nome: Steve Carell -> 27 filmes
# Nome: Jamie Foxx -> 26 filmes
# Nome: Gary Oldman -> 26 filmes
# Nome: John Cusack -> 26 filmes
# Nome: Charlize Theron -> 26 filmes
# Nome: Mark Ruffalo -> 26 filmes
# Nome: Naomi Watts -> 26 filmes
# Nome: Liam Neeson -> 26 filmes
# Nome: Adam Sandler -> 25 filmes
# Nome: George Clooney -> 25 filmes
# Nome: Matthew McConaughey -> 25 filmes
# Nome: Jude Law -> 25 filmes
# Nome: Jake Gyllenhaal -> 25 filmes
# Nome: Catherine Keener -> 25 filmes
# Nome: Paul Rudd -> 25 filmes
# Nome: Meryl Streep -> 25 filmes
# Nome: Elizabeth Banks -> 25 filmes
# Nome: Channing Tatum -> 25 filmes
# Nome: Ben Affleck -> 24 filmes
# Nome: Sam Rockwell -> 24 filmes
# Nome: Gerard Butler -> 24 filmes
# Nome: Greg Kinnear -> 24 filmes
# Nome: Julianne Moore -> 24 filmes
# Nome: Justin Long -> 24 filmes
# Nome: Anne Hathaway -> 24 filmes
# Nome: Bradley Cooper -> 24 filmes
# Nome: Kristen Bell -> 24 filmes
# Nome: Kristen Wiig -> 24 filmes
# Nome: Christian Bale -> 23 filmes
# Nome: Cameron Diaz -> 23 filmes
# Nome: Julia Roberts -> 23 filmes
# Nome: Michael Caine -> 23 filmes
# Nome: Cate Blanchett -> 23 filmes
# Nome: Anna Faris -> 23 filmes
# Nome: Jason Statham -> 23 filmes
# Nome: Brad Pitt -> 23 filmes
# Nome: . -> 23 filmes
# Nome: Anthony Hopkins -> 23 filmes
# Nome: Jennifer Aniston -> 23 filmes
# Nome: Robin Williams -> 23 filmes
# Nome: Anthony Mackie -> 23 filmes
# Nome: Idris Elba -> 23 filmes
# Nome: Anna Kendrick -> 23 filmes
# Nome: Angelina Jolie -> 22 filmes
# Nome: Ethan Hawke -> 22 filmes
# Nome: Luke Wilson -> 22 filmes
# Nome: Ice Cube -> 22 filmes
# Nome: John C. Reilly -> 22 filmes
# Nome: Ed Harris -> 22 filmes
# Nome: Danny Glover -> 22 filmes
# Nome: Amy Adams -> 22 filmes
# Nome: Terrence Howard -> 22 filmes
# Nome: Reese Witherspoon -> 22 filmes
# Nome: Jonah Hill -> 22 filmes
# Nome: Michael Peña -> 22 filmes
# Nome: Forest Whitaker -> 21 filmes
# Nome: Antonio Banderas -> 21 filmes
# Nome: the -> 21 filmes
# Nome: Christopher Walken -> 21 filmes
# Nome: Denzel Washington -> 21 filmes
# Nome: Ben Kingsley -> 21 filmes
# Nome: Steve Buscemi -> 21 filmes
# Nome: Rosario Dawson -> 21 filmes
# Nome: Chris Evans -> 21 filmes
# Nome: Richard Jenkins -> 21 filmes
# Nome: Seth Rogen -> 21 filmes
# Nome: Kate Hudson -> 20 filmes
# Nome: Willem Dafoe -> 20 filmes
# Nome: Vin Diesel -> 20 filmes
# Nome: Tom Hanks -> 20 filmes
# Nome: Don Cheadle -> 20 filmes
# Nome: Kate Beckinsale -> 20 filmes
# Nome: Josh Brolin -> 20 filmes
# Nome: Amanda Peet -> 20 filmes
# Nome: Michael Douglas -> 20 filmes
# Nome: Marisa Tomei -> 20 filmes
# Nome: Natalie Portman -> 20 filmes
# Nome: Billy Bob Thornton -> 20 filmes
# Nome: Helen Mirren -> 20 filmes
# Nome: Jessica Biel -> 20 filmes
# Nome: Zoe Saldana -> 20 filmes
# Nome: Kristen Stewart -> 20 filmes
# Nome: Kevin Hart -> 20 filmes
# Nome: Patrick Wilson -> 20 filmes
# Nome: Zac Efron -> 20 filmes
# Nome: Emily Blunt -> 20 filmes
# Nome: Emma Stone -> 20 filmes
# Nome: Richard Gere -> 19 filmes
# Nome: John Travolta -> 19 filmes
# Nome: Jeff Bridges -> 19 filmes
# Nome: Keanu Reeves -> 19 filmes
# Nome: Joaquin Phoenix -> 19 filmes
# Nome: Chris Cooper -> 19 filmes
# Nome: Tom Cruise -> 19 filmes
# Nome: Tommy Lee Jones -> 19 filmes
# Nome: Robert Downey, Jr. -> 19 filmes
# Nome: Dakota Fanning -> 19 filmes
# Nome: Queen Latifah -> 19 filmes
# Nome: John Leguizamo -> 19 filmes
# Nome: Jennifer Garner -> 19 filmes
# Nome: Shia LaBeouf -> 19 filmes
# Nome: Jessica Alba -> 19 filmes
# Nome: Amanda Seyfried -> 19 filmes
# Nome: Rose Byrne -> 19 filmes
# Nome: Emma Roberts -> 19 filmes
# Nome: Sandra Bullock -> 18 filmes
# Nome: Robert Duvall -> 18 filmes
# Nome: Leonardo DiCaprio -> 18 filmes
# Nome: Kirsten Dunst -> 18 filmes
# Nome: Jennifer Lopez -> 18 filmes
# Nome: Vince Vaughn -> 18 filmes
# Nome: Drew Barrymore -> 18 filmes
# Nome: Bill Murray -> 18 filmes
# Nome: Alfred Molina -> 18 filmes
# Nome: Seann William Scott -> 18 filmes
# Nome: Aaron Eckhart -> 18 filmes
# Nome: Russell Crowe -> 18 filmes
# Nome: Jim Carrey -> 18 filmes
# Nome: Will Smith -> 18 filmes
# Nome: Renée Zellweger -> 18 filmes
# Nome: Jennifer Connelly -> 18 filmes
# Nome: Allison Janney -> 14 filmes
# Nome: Eric Bana -> 14 filmes
# Nome: Evan Rachel Wood -> 14 filmes
# Nome: Keira Knightley -> 14 filmes
# Nome: Bobby Cannavale -> 14 filmes
# Nome: Michelle Williams -> 14 filmes
# Nome: Bill Nighy -> 14 filmes
# Nome: Kevin James -> 14 filmes
# Nome: Will Arnett -> 14 filmes
# Nome: Michelle Monaghan -> 14 filmes
# Nome: Bill Hader -> 14 filmes
# Nome: Taraji P. Henson -> 14 filmes
# Nome: Josh Gad -> 14 filmes
# Nome: Oscar Isaac -> 14 filmes
# Nome: Glenn Close -> 13 filmes
# Nome: Donald Sutherland -> 13 filmes
# Nome: Barry Pepper -> 13 filmes
# Nome: Gabrielle Union -> 13 filmes
# Nome: Brittany Murphy -> 13 filmes
# Nome: Laura Dern -> 13 filmes
# Nome: Josh Hartnett -> 13 filmes
# Nome: Cedric the Entertainer -> 13 filmes
# Nome: Bernie Mac -> 13 filmes
# Nome: Kerry Washington -> 13 filmes
# Nome: Tom Wilkinson -> 13 filmes
# Nome: Ian McShane -> 13 filmes
# Nome: Jeffrey Wright -> 13 filmes
# Nome: Jackie Chan -> 13 filmes
# Nome: Michelle Pfeiffer -> 13 filmes
# Nome: Annette Bening -> 13 filmes
# Nome: Ashley Judd -> 13 filmes
# Nome: Kurt Russell -> 13 filmes
# Nome: Adrien Brody -> 13 filmes
# Nome: Tom Hardy -> 13 filmes
# Nome: Sean Bean -> 13 filmes
# Nome: Anthony Anderson -> 13 filmes
# Nome: James Woods -> 13 filmes
# Nome: Tim Allen -> 13 filmes
# Nome: Christina Applegate -> 13 filmes
# Nome: Ron Perlman -> 13 filmes
# Nome: Alan Rickman -> 13 filmes
# Nome: Maggie Grace -> 13 filmes
# Nome: Adam Brody -> 13 filmes
# Nome: Michael Sheen -> 13 filmes
# Nome: Amy Poehler -> 13 filmes
# Nome: Topher Grace -> 13 filmes
# Nome: George Lopez -> 13 filmes
# Nome: Blake Lively -> 13 filmes
# Nome: James McAvoy -> 13 filmes
# Nome: Andy Samberg -> 13 filmes
# Nome: John Krasinski -> 13 filmes
# Nome: Ed Helms -> 13 filmes
# Nome: Ken Jeong -> 13 filmes
# Nome: Rob Riggle -> 13 filmes
# Nome: Michael Fassbender -> 13 filmes
# Nome: Jessica Chastain -> 13 filmes
# Nome: Jason Lee -> 12 filmes
# Nome: Chloë Sevigny -> 12 filmes
# Nome: Kiefer Sutherland -> 12 filmes
# Nome: Martin Lawrence -> 12 filmes
# Nome: Kim Basinger -> 12 filmes
# Nome: Christina Ricci -> 12 filmes
# Nome: Judi Dench -> 12 filmes
# Nome: Marlon Wayans -> 12 filmes
# Nome: Anjelica Huston -> 12 filmes
# Nome: Lisa Kudrow -> 12 filmes
# Nome: Benjamin Bratt -> 12 filmes
# Nome: Harvey Keitel -> 12 filmes
# Nome: Cuba Gooding, Jr. -> 12 filmes
# Nome: Heath Ledger -> 12 filmes
# Nome: Jason Isaacs -> 12 filmes
# Nome: David Arquette -> 12 filmes
# Nome: Emily Mortimer -> 12 filmes
# Nome: Ian McKellen -> 12 filmes
# Nome: Edward Burns -> 12 filmes
# Nome: Jennifer Jason Leigh -> 12 filmes
# Nome: Heather Graham -> 12 filmes
# Nome: Michael Gambon -> 12 filmes
# Nome: Maggie Smith -> 12 filmes
# Nome: John Hawkes -> 12 filmes
# Nome: Daniel Radcliffe -> 12 filmes
# Nome: Paul Bettany -> 12 filmes
# Nome: Matthew Lillard -> 12 filmes
# Nome: Kathy Bates -> 12 filmes
# Nome: Kate Bosworth -> 12 filmes
# Nome: Emily Watson -> 12 filmes
# Nome: Karl Urban -> 12 filmes
# Nome: Mary-Louise Parker -> 12 filmes
# Nome: Jason Segel -> 12 filmes
# Nome: Ron Livingston -> 12 filmes
# Nome: Hilary Duff -> 12 filmes
# Nome: Diego Luna -> 12 filmes
# Nome: John Cho -> 12 filmes
# Nome: Robert Pattinson -> 12 filmes
# Nome: Jason Clarke -> 12 filmes
# Nome: David Cross -> 12 filmes
# Nome: Simon Pegg -> 12 filmes
# Nome: Elizabeth Olsen -> 12 filmes
# Nome: Rebecca Hall -> 12 filmes
# Nome: Jeremy Renner -> 12 filmes
# Nome: Malin Åkerman -> 12 filmes
# Nome: Isla Fisher -> 12 filmes
# Nome: Amber Heard -> 12 filmes
# Nome: Common -> 12 filmes
# Nome: Elle Fanning -> 12 filmes
# Nome: Jon Hamm -> 12 filmes
# Nome: Melissa McCarthy -> 12 filmes
# Nome: Dave Franco -> 12 filmes
# Nome: Octavia Spencer -> 12 filmes
# Nome: Viggo Mortensen -> 11 filmes
# Nome: Billy Crudup -> 11 filmes
# Nome: Djimon Hounsou -> 11 filmes
# Nome: Diane Keaton -> 11 filmes
# Nome: Molly Shannon -> 11 filmes
# Nome: Nathan Lane -> 11 filmes
# Nome: Hope Davis -> 11 filmes
# Nome: Tim Robbins -> 11 filmes
# Nome: Thandie Newton -> 11 filmes
# Nome: Ray Winstone -> 11 filmes
# Nome: Michael Clarke Duncan -> 11 filmes
# Nome: Kevin Pollak -> 11 filmes
# Nome: Tobey Maguire -> 11 filmes
# Nome: James Caan -> 11 filmes
# Nome: Matthew Broderick -> 11 filmes
# Nome: William Hurt -> 11 filmes
# Nome: Jeff Goldblum -> 11 filmes
# Nome: Robbie Coltrane -> 11 filmes
# Nome: Selma Blair -> 11 filmes
# Nome: Hugo Weaving -> 11 filmes
# Nome: Steve Martin -> 11 filmes
# Nome: Kris Kristofferson -> 11 filmes
# Nome: Mandy Moore -> 11 filmes
# Nome: Hank Azaria -> 11 filmes
# Nome: Arnold Schwarzenegger -> 11 filmes
# Nome: Juliette Lewis -> 11 filmes
# Nome: Sam Shepard -> 11 filmes
# Nome: Emma Thompson -> 11 filmes
# Nome: Logan Lerman -> 11 filmes
# Nome: Meagan Good -> 11 filmes
# Nome: Neil Patrick Harris -> 11 filmes
# Nome: Tina Fey -> 11 filmes
# Nome: Diane Kruger -> 11 filmes
# Nome: Mary Elizabeth Winstead -> 11 filmes
# Nome: Sebastian Stan -> 11 filmes
# Nome: Rosamund Pike -> 9 filmes
# Nome: Aubrey Plaza -> 9 filmes
# Nome: Hailee Steinfeld -> 9 filmes
# Nome: Christina Hendricks -> 9 filmes
# Nome: Riley Keough -> 9 filmes
# Nome: Frank Grillo -> 9 filmes
# Nome: Nick Offerman -> 9 filmes
# Nome: Jacki Weaver -> 9 filmes
# Nome: Margot Robbie -> 9 filmes
# Nome: Piper Perabo -> 8 filmes
# Nome: Lucas Black -> 8 filmes
# Nome: Bruce Dern -> 8 filmes
# Nome: Patrick Fugit -> 8 filmes
# Nome: Edward Furlong -> 8 filmes
# Nome: Jada Pinkett Smith -> 8 filmes
# Nome: Catherine O'Hara -> 8 filmes
# Nome: Jennifer Coolidge -> 8 filmes
# Nome: Frances Fisher -> 8 filmes
# Nome: Jesse Bradford -> 8 filmes
# Nome: Zach Braff -> 8 filmes
# Nome: Crispin Glover -> 8 filmes
# Nome: Burt Reynolds -> 8 filmes
# Nome: Jamie Lee Curtis -> 8 filmes
# Nome: David Spade -> 8 filmes
# Nome: Téa Leoni -> 8 filmes
# Nome: Ali Larter -> 8 filmes
# Nome: Connie Nielsen -> 8 filmes
# Nome: Lena Headey -> 8 filmes
# Nome: Meg Ryan -> 8 filmes
# Nome: Leelee Sobieski -> 8 filmes
# Nome: Elisabeth Shue -> 8 filmes
# Nome: Dan Aykroyd -> 8 filmes
# Nome: Stacy Keach -> 8 filmes
# Nome: Timothy Hutton -> 8 filmes
# Nome: Tim Roth -> 8 filmes
# Nome: Candice Bergen -> 8 filmes
# Nome: Jerry O'Connell -> 8 filmes
# Nome: Frankie Muniz -> 8 filmes
# Nome: Wanda Sykes -> 8 filmes
# Nome: Demi Moore -> 8 filmes
# Nome: Gene Hackman -> 8 filmes
# Nome: Ellen Burstyn -> 8 filmes
# Nome: David Duchovny -> 8 filmes
# Nome: Breckin Meyer -> 8 filmes
# Nome: Patrick Dempsey -> 8 filmes
# Nome: Hugh Grant -> 8 filmes
# Nome: Mark Webber -> 8 filmes
# Nome: Jonathan Pryce -> 8 filmes
# Nome: Rob Schneider -> 8 filmes
# Nome: Cary Elwes -> 8 filmes
# Nome: Joseph Fiennes -> 8 filmes
# Nome: Tobin Bell -> 8 filmes
# Nome: Shannyn Sossamon -> 8 filmes
# Nome: Albert Brooks -> 8 filmes
# Nome: Simon Baker -> 8 filmes
# Nome: Taye Diggs -> 8 filmes
# Nome: Cliff Curtis -> 8 filmes
# Nome: Scott Speedman -> 8 filmes
# Nome: Debra Messing -> 8 filmes
# Nome: Anne Heche -> 8 filmes
# Nome: Bow Wow -> 8 filmes
# Nome: Luis Guzmán -> 8 filmes
# Nome: Jeff Garlin -> 8 filmes
# Nome: Chad Michael Murray -> 8 filmes
# Nome: Charles S. Dutton -> 8 filmes
# Nome: Charlie Sheen -> 8 filmes
# Nome: Peter Dinklage -> 8 filmes
# Nome: Sienna Miller -> 8 filmes
# Nome: Michelle Trachtenberg -> 8 filmes
# Nome: Doug Jones -> 8 filmes
# Nome: Chiwetel Ejiofor -> 8 filmes
# Nome: Gael García Bernal -> 8 filmes
# Nome: Hayden Panettiere -> 8 filmes
# Nome: Philip Baker Hall -> 8 filmes
# Nome: Garrett Hedlund -> 8 filmes
# Nome: Boris Kodjoe -> 8 filmes
# Nome: David Strathairn -> 8 filmes
# Nome: Jenny Slate -> 8 filmes
# Nome: Olivia Munn -> 8 filmes
# Nome: Jeremy Piven -> 8 filmes
# Nome: Ben Whishaw -> 8 filmes
# Nome: Milo Ventimiglia -> 8 filmes
# Nome: Bill Pullman -> 8 filmes
# Nome: John Ortiz -> 8 filmes
# Nome: Ellen Page -> 8 filmes
# Nome: Dan Fogler -> 8 filmes
# Nome: The -> 8 filmes
# Nome: Fred Armisen -> 8 filmes
# Nome: Rainn Wilson -> 8 filmes
# Nome: Teresa Palmer -> 8 filmes
# Nome: Lake Bell -> 8 filmes
# Nome: Clark Duke -> 8 filmes
# Nome: Ashley Greene -> 8 filmes
# Nome: Eddie Marsan -> 8 filmes
# Nome: Mia Wasikowska -> 8 filmes
# Nome: Charlie Day -> 8 filmes
# Nome: Kristen Schaal -> 8 filmes
# Nome: Carey Mulligan -> 8 filmes
# Nome: Greta Gerwig -> 8 filmes
# Nome: Liam Hemsworth -> 8 filmes
# Nome: Kevin Durand -> 8 filmes
# Nome: Rashida Jones -> 8 filmes
# Nome: Imogen Poots -> 8 filmes
# Nome: Nick Frost -> 8 filmes
# Nome: Analeigh Tipton -> 8 filmes
# Nome: Shailene Woodley -> 8 filmes
# Nome: David Oyelowo -> 8 filmes
# Nome: Luke Evans -> 8 filmes
# Nome: Tom Hiddleston -> 8 filmes
# Nome: Dakota Johnson -> 8 filmes
# Nome: Benedict Cumberbatch -> 8 filmes
# Nome: Dan Stevens -> 8 filmes
# Nome: Kimberly Elise -> 7 filmes
# Nome: Michael Rapaport -> 7 filmes
# Nome: Billy Connolly -> 7 filmes
# Nome: Nia Long -> 7 filmes
# Nome: Eliza Dushku -> 7 filmes
# Nome: Alicia Witt -> 7 filmes
# Nome: Adrian Grenier -> 7 filmes
# Nome: Joan Allen -> 7 filmes
# Nome: Kenneth Branagh -> 7 filmes
# Nome: Dennis Haysbert -> 7 filmes
# Nome: Robert Forster -> 7 filmes
# Nome: Teri Polo -> 7 filmes
# Nome: David Schwimmer -> 7 filmes
# Nome: Keith David -> 7 filmes
# Nome: Courteney Cox -> 7 filmes
# Nome: Jamie Kennedy -> 7 filmes
# Nome: Dylan Baker -> 7 filmes
# Nome: Clifton Collins, Jr. -> 7 filmes
# Nome: Jim Cummings -> 7 filmes
# Nome: Monica Bellucci -> 7 filmes
# Nome: Billy Crystal -> 7 filmes
# Nome: Shannon Elizabeth -> 7 filmes
# Nome: Billy Zane -> 7 filmes
# Nome: Eddie Griffin -> 7 filmes
# Nome: Orlando Jones -> 7 filmes
# Nome: Gina Gershon -> 7 filmes
# Nome: Jordana Brewster -> 7 filmes
# Nome: Rip Torn -> 7 filmes
# Nome: Method Man -> 7 filmes
# Nome: Rhys Ifans -> 7 filmes
# Nome: Miranda Otto -> 7 filmes
# Nome: Demián Bichir -> 7 filmes
# Nome: Dominic Cooper -> 7 filmes
# Nome: Ariel Winter -> 7 filmes
# Nome: Gugu Mbatha-Raw -> 7 filmes
# Nome: Alison Brie -> 7 filmes
# Nome: Carmen Ejogo -> 7 filmes
# Nome: Rebel Wilson -> 7 filmes
# Nome: Jesse Plemons -> 7 filmes
# Nome: Michael B. Jordan -> 7 filmes
# Nome: James Badge Dale -> 7 filmes
# Nome: Jake Johnson -> 7 filmes
# Nome: Tika Sumpter -> 7 filmes
# Nome: Theo James -> 7 filmes
# Nome: Alicia Vikander -> 7 filmes
# Nome: Gérard Depardieu -> 6 filmes
# Nome: Jimmy Smits -> 6 filmes
# Nome: Henry Thomas -> 6 filmes
# Nome: Minnie Driver -> 6 filmes
# Nome: Omar Epps -> 6 filmes
# Nome: Peter Gallagher -> 6 filmes
# Nome: Juliette Binoche -> 6 filmes
# Nome: Lena Olin -> 6 filmes
# Nome: Bette Midler -> 6 filmes
# Nome: James Caviezel -> 6 filmes
# Nome: Olga Kurylenko -> 6 filmes
# Nome: Lili Taylor -> 6 filmes
# Nome: Robin Wright Penn -> 6 filmes
# Nome: Bruce Campbell -> 6 filmes
# Nome: Ian Holm -> 6 filmes
# Nome: Patricia Arquette -> 6 filmes
# Nome: Mena Suvari -> 6 filmes
# Nome: Gary Sinise -> 6 filmes
# Nome: of -> 6 filmes
# Nome: Haley Joel Osment -> 6 filmes
# Nome: Woody Allen -> 6 filmes
# Nome: Lauren Ambrose -> 6 filmes
# Nome: Tom Arnold -> 6 filmes
# Nome: Dennis Farina -> 6 filmes
# Nome: Aidan Quinn -> 6 filmes
# Nome: Clint Eastwood -> 6 filmes
# Nome: Courtney B. Vance -> 6 filmes
# Nome: James Spader -> 6 filmes
# Nome: Matthew Davis -> 6 filmes
# Nome: Kristin Scott Thomas -> 6 filmes
# Nome: Jennifer Morrison -> 6 filmes
# Nome: Chris O'Donnell -> 6 filmes
# Nome: Alan Alda -> 6 filmes
# Nome: Shane West -> 6 filmes
# Nome: Sally Field -> 6 filmes
# Nome: Cloris Leachman -> 6 filmes
# Nome: Jeremy Sisto -> 6 filmes
# Nome: Til Schweiger -> 6 filmes
# Nome: Bob Hoskins -> 6 filmes
# Nome: Martin Short -> 6 filmes
# Nome: Alessandro Nivola -> 6 filmes
# Nome: Rufus Sewell -> 6 filmes
# Nome: Dennis Hopper -> 6 filmes
# Nome: Victor Garber -> 6 filmes
# Nome: Justin Theroux -> 6 filmes
# Nome: Jaime Pressly -> 6 filmes
# Nome: Cuba Gooding Jr. -> 6 filmes
# Nome: Giancarlo Esposito -> 6 filmes
# Nome: Julie Andrews -> 6 filmes
# Nome: Rory Cochrane -> 6 filmes
# Nome: Tony Shalhoub -> 6 filmes
# Nome: Randy Quaid -> 6 filmes
# Nome: Amanda Bynes -> 6 filmes
# Nome: Vincent Cassel -> 6 filmes
# Nome: Martin Sheen -> 6 filmes
# Nome: Elias Koteas -> 6 filmes
# Nome: Diedrich Bader -> 6 filmes
# Nome: Daniel Day-Lewis -> 6 filmes
# Nome: Jim Broadbent -> 6 filmes
# Nome: Isaiah Washington -> 6 filmes
# Nome: Anthony LaPaglia -> 6 filmes
# Nome: Michael Pitt -> 6 filmes
# Nome: Kal Penn -> 6 filmes
# Nome: the life of -> 6 filmes
# Nome: Campbell Scott -> 6 filmes
# Nome: Rebecca Romijn -> 6 filmes
# Nome: Peter Facinelli -> 6 filmes
# Nome: Rory Culkin -> 6 filmes
# Nome: Daryl Hannah -> 6 filmes
# Nome: Alison Lohman -> 6 filmes
# Nome: Marton Csokas -> 6 filmes
# Nome: Shea Whigham -> 6 filmes
# Nome: Donnie Wahlberg -> 6 filmes
# Nome: Ken Watanabe -> 6 filmes
# Nome: Terence Stamp -> 6 filmes
# Nome: Bridget Moynahan -> 6 filmes
# Nome: Sandra Oh -> 6 filmes
# Nome: Dylan McDermott -> 6 filmes
# Nome: Dominic Purcell -> 6 filmes
# Nome: Matthew Goode -> 6 filmes
# Nome: Dominic West -> 6 filmes
# Nome: John Hurt -> 6 filmes
# Nome: Alan Tudyk -> 6 filmes
# Nome: Michael Parks -> 6 filmes
# Nome: Jonathan Rhys Meyers -> 6 filmes
# Nome: Jean-Claude Van Damme -> 6 filmes
# Nome: Loretta Devine -> 6 filmes
# Nome: Camilla Belle -> 6 filmes
# Nome: Cicely Tyson -> 6 filmes
# Nome: Max Minghella -> 6 filmes
# Nome: 50 Cent -> 6 filmes
# Nome: Martin Freeman -> 6 filmes
# Nome: Eva Green -> 6 filmes
# Nome: Lukas Haas -> 6 filmes
# Nome: Shawnee Smith -> 6 filmes
# Nome: Beau Bridges -> 6 filmes
# Nome: Kristin Davis -> 6 filmes
# Nome: Costas Mandylor -> 6 filmes
# Nome: Lee Pace -> 6 filmes
# Nome: Leighton Meester -> 6 filmes
# Nome: Michael C. Hall -> 6 filmes
# Nome: Mischa Barton -> 6 filmes
# Nome: Jodelle Ferland -> 6 filmes
# Nome: Matthew Fox -> 6 filmes
# Nome: Joe Anderson -> 6 filmes
# Nome: Thomas Lennon -> 6 filmes
# Nome: Imelda Staunton -> 6 filmes
# Nome: Wendi McLendon-Covey -> 6 filmes
# Nome: Jenna Fischer -> 6 filmes
# Nome: Robert Downey Jr. -> 6 filmes
# Nome: Asa Butterfield -> 6 filmes
# Nome: Lizzy Caplan -> 6 filmes
# Nome: Jenifer Lewis -> 6 filmes
# Nome: Michael Ealy -> 6 filmes
# Nome: Kat Dennings -> 6 filmes
# Nome: Alice Braga -> 6 filmes
# Nome: Aidan Gillen -> 6 filmes
# Nome: Adewale Akinnuoye-Agbaje -> 6 filmes
# Nome: Jemaine Clement -> 6 filmes
# Nome: Marion Cotillard -> 6 filmes
# Nome: Kodi Smit-McPhee -> 6 filmes
# Nome: Jack McBrayer -> 6 filmes
# Nome: Devon Bostick -> 6 filmes
# Nome: Elizabeth Reaser -> 6 filmes
# Nome: Jackson Rathbone -> 6 filmes
# Nome: Dolph Lundgren -> 6 filmes
# Nome: Madeline Carroll -> 6 filmes
# Nome: Jessica Harper -> 1 filmes
# Nome: Justin Bruening -> 1 filmes
# Nome: Jason George -> 1 filmes
# Nome: Michael O'Neill -> 1 filmes
# Nome: Eric Close -> 1 filmes
# Nome: Tanner Stine -> 1 filmes
# Nome: Skye P. Marshall -> 1 filmes
# Nome: Misty Copeland -> 1 filmes
# Nome: Gwilym Lee -> 1 filmes
# Nome: Allen Leech -> 1 filmes
# Nome: Calum Worthy -> 1 filmes
# Nome: Rory Uphold -> 1 filmes
# Nome: Dumbfoundead -> 1 filmes
# Nome: Cameron Seely -> 1 filmes
# Nome: Pharrell Williams -> 1 filmes
# Nome: Sverrir Gudnason -> 1 filmes
# Nome: Jovan Adepo -> 1 filmes
# Nome: Jacob Anderson -> 1 filmes
# Nome: Dominic Applewhite -> 1 filmes
# Nome: Iain De Caestecker -> 1 filmes
# Nome: Mathilde Ollivier -> 1 filmes
# Nome: Shaun Cairo (Screenplay) -> 1 filmes
# Nome: Jo Marie Payton -> 1 filmes
# Nome: Gary Leroi Gray -> 1 filmes
# Nome: Paula Jai Parker -> 1 filmes
# Nome: Alison Sudol -> 1 filmes
# Nome: William Nadylam -> 1 filmes
# Nome: Poppy Corby-Tuech -> 1 filmes
# Nome: Tig Notaro -> 1 filmes
# Nome: Florian Munteanu -> 1 filmes
# Nome: Andre Ward -> 1 filmes
# Nome: Olivia Colman -> 1 filmes
# Nome: Ella Hunt -> 1 filmes
# Nome: Malcolm Cumming -> 1 filmes
# Nome: Marli Siu -> 1 filmes
# Nome: Sarah Swire -> 1 filmes
# Nome: Christopher Leveaux -> 1 filmes
# Nome: Ben Wiggins -> 1 filmes
# Nome: Kiki Layne -> 1 filmes
# Nome: Teyonah Parris -> 1 filmes
# Nome: Martin Compston -> 1 filmes
# Nome: Zosia Mamet -> 1 filmes
# Nome: Jimmi Simpson -> 1 filmes
# Nome: Luke Baines -> 1 filmes
# Nome: Patrick Fischler -> 1 filmes
# Nome: C-Pudding -> 1 filmes
# Nome: Poundcake -> 1 filmes
# Nome: Tyga & Raw Dawg -> 1 filmes
# Nome: Sweet Tea -> 1 filmes
# Nome: Young Rider -> 1 filmes
# Nome: Blaze -> 1 filmes
# Nome: Michele -> 1 filmes
# Nome: Double Trouble -> 1 filmes
# Nome: Satan -> 1 filmes
# Nome: Fever -> 1 filmes
# Nome: Hera Hilmar -> 1 filmes
# Nome: Jihae -> 1 filmes
# Nome: Ronan Raftery -> 1 filmes
# Nome: Leila George -> 1 filmes
# Nome: Patrick Malahide -> 1 filmes
# Nome: John Mulaney -> 1 filmes
# Nome: Kimiko Glenn -> 1 filmes
# Nome: Nicholas Cage -> 1 filmes
# Nome: Andy Garcia -> 1 filmes
# Nome: Leah Remini -> 1 filmes
# Nome: Annaleigh Ashford -> 1 filmes
# Nome: Jason Drucker -> 1 filmes
# Nome: Rachel Crow -> 1 filmes
# Nome: Pamela Adlon -> 1 filmes
# Nome: Falk Hentschel -> 1 filmes
# Nome: Janelle Monáe -> 1 filmes
# Nome: Eiza Gonzalez -> 1 filmes
